# %%
import torch
from torch import nn
from torch import optim
import numpy as np

# %%
dataset = "D:\wahab stuff\wahab code\Draw-C-Ai\data\raw"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Wahab\AppData\Local\Temp\ipykernel_8344\234938829.py:1: SyntaxWarning: invalid escape sequence '\w'
#   dataset = "D:\wahab stuff\wahab code\Draw-C-Ai\data\raw"

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__() 
        self.conv2d1 = nn.Conv2d(in_channels = 1, out_channels = 16,kernel_size = 3)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size = 2 , stride = 2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(in_features = 3600 ,out_features = 8)

    def forward(self,x):
        x = self.conv2d1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.flatten(x)
        x = self.fc1(x)
        return x
